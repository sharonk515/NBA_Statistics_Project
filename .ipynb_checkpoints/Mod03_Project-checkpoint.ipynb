# %%
import requests
import json
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import statsmodels.api as sm
from scipy.stats import stats

import time

# %% [markdown]
# # Game Data

# %% [markdown]
# ## Creating function to request data

# %%
def get_game_data(per_page=100, total_pages=None):

    # Get the last page from the meta data
    url = 'https://www.balldontlie.io/api/v1/games'
    parameters = {'per_page': per_page, 'page': 1}
    resp = requests.get(url, params = parameters).json()
    total_pages = resp['meta']['total_pages'] if total_pages is None else total_pages
    
    # Initialize data frame 
    game_data = pd.DataFrame()
    
    start_time = time.time()
    
    # Loop to iterate through all pages
    for page in range(1, total_pages+1):
        
        # Making the request
        url = 'https://www.balldontlie.io/api/v1/games'
        parameters = {'per_page': per_page, 'page': page}
        resp = requests.get(url, params = parameters).json()

        # Creating dataframe from the data key
        data = pd.DataFrame.from_records(resp['data'])

        # Creating columns out of the 'home_team' and 'visitor_team' column (these columns had dictionary values)
        for k in data['home_team'][0].keys():
            data['home_'+k] = data['home_team'].apply(lambda x: x[k])
        for k in data['visitor_team'][0].keys():
            data['visitor_'+k] = data['visitor_team'].apply(lambda x: x[k])
        
        # Filter data to only show East vs West games
        data = data.loc[((data['home_conference']=="East") & (data['visitor_conference']=="West")) 
                        | ((data['home_conference']=="West") & (data['visitor_conference']=="East"))]
        
        # Column to display which page results came from
        data['Page'] = page
        
        # Concatenate our initial datafram with dataframe from each loop
        game_data = pd.concat([game_data, data])
        
        # Delay between requests
        time.sleep(0.8)
    
    # Convert the date column to date (dt.tz_localize is used to remove toe T-Z string)
    game_data['date'] = pd.to_datetime(game_data['date'], errors='coerce').dt.tz_localize(None)
    
    end_time = time.time()
    print(end_time - start_time)
    
    return game_data

# %%
game_data = get_game_data(per_page=100, total_pages=10)
#game_data = get_game_data()
# Out:
# 13.34564733505249

# %%
game_data.head()
# Out:
#          date                                          home_team  \
# 1  2019-02-09  {'id': 2, 'abbreviation': 'BOS', 'city': 'Bost...
# 2  2019-02-08  {'id': 23, 'abbreviation': 'PHI', 'city': 'Phi...
# 4  2019-02-08  {'id': 26, 'abbreviation': 'SAC', 'city': 'Sac...
# 12 2019-02-10  {'id': 23, 'abbreviation': 'PHI', 'city': 'Phi...
# 16 2019-02-10  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...
#
#     home_team_score     id  period  postseason  season status   time  \
# 1               112  48751       4       False    2018  Final
# 2               117  48739       4       False    2018  Final
# 4               102  48746       4       False    2018  Final
# 12              143  48760       4       False    2018  Final
# 16              120  48759       4       False    2018  Final
#
#                                          visitor_team  ...  \
# 1   {'id': 13, 'abbreviation': 'LAC', 'city': 'LA'...  ...
# 2   {'id': 8, 'abbreviation': 'DEN', 'city': 'Denv...  ...
# 4   {'id': 16, 'abbreviation': 'MIA', 'city': 'Mia...  ...
# 12  {'id': 14, 'abbreviation': 'LAL', 'city': 'Los...  ...
# 16  {'id': 16, 'abbreviation': 'MIA', 'city': 'Mia...  ...
#
#            home_full_name  home_name visitor_id visitor_abbreviation  \
# 1          Boston Celtics    Celtics         13                  LAC
# 2      Philadelphia 76ers      76ers          8                  DEN
# 4        Sacramento Kings      Kings         16                  MIA
# 12     Philadelphia 76ers      76ers         14                  LAL
# 16  Golden State Warriors   Warriors         16                  MIA
#
#    visitor_city visitor_conference visitor_division   visitor_full_name  \
# 1            LA               West          Pacific         LA Clippers
# 2        Denver               West        Northwest      Denver Nuggets
# 4         Miami               East        Southeast          Miami Heat
# 12  Los Angeles               West          Pacific  Los Angeles Lakers
# 16        Miami               East        Southeast          Miami Heat
#
#     visitor_name Page
# 1       Clippers    1
# 2        Nuggets    1
# 4           Heat    1
# 12        Lakers    1
# 16          Heat    1
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Creating function to shape dataframe

# %% [markdown]
# id, East Score, West Score

# %%
def reshape_data(data):
    
    data['East_Team'] = np.where(data['home_conference']=="East", data['home_full_name'], data['visitor_full_name'])
    data['East_Score'] = np.where(data['home_conference']=="East", data['home_team_score'], data['visitor_team_score'])
    
    data['West_Team'] = np.where(data['home_conference']=="West", data['home_full_name'], data['visitor_full_name'])
    data['West_Score'] = np.where(data['home_conference']=="West", data['home_team_score'], data['visitor_team_score'])
    
    data['West_Minus_East'] = data['West_Score'] - data['East_Score']
    
    data = data[['id', 'date', 'East_Team', 'East_Score', 'West_Team', 'West_Score', 'West_Minus_East']]
    return data

# %%
game_data_reshaped = reshape_data(game_data)

# %%
game_data_reshaped.head(20)
# Out:
#        id       date            East_Team  East_Score               West_Team  \
# 1   48751 2019-02-09       Boston Celtics         112             LA Clippers
# 2   48739 2019-02-08   Philadelphia 76ers         117          Denver Nuggets
# 4   48746 2019-02-08           Miami Heat          96        Sacramento Kings
# 12  48760 2019-02-10   Philadelphia 76ers         143      Los Angeles Lakers
# 16  48759 2019-02-10           Miami Heat         118   Golden State Warriors
# 20  48770 2019-02-12        Atlanta Hawks         117      Los Angeles Lakers
# 27  48773 2019-02-12        Orlando Magic         118    New Orleans Pelicans
# 33  48780 2019-02-13        Chicago Bulls         122       Memphis Grizzlies
# 35  48806 2019-02-23  Cleveland Cavaliers         112       Memphis Grizzlies
# 38  48782 2019-02-13           Miami Heat         112        Dallas Mavericks
# 42  48834 2019-02-27    Charlotte Hornets         113         Houston Rockets
# 44  48829 2019-02-25   Philadelphia 76ers         111    New Orleans Pelicans
# 48  48845 2019-02-28       Indiana Pacers         122  Minnesota Timberwolves
# 51  48875 2019-03-04        Brooklyn Nets         127        Dallas Mavericks
# 52  48887 2019-03-05       Boston Celtics         128   Golden State Warriors
# 54  48890 2019-03-06   Washington Wizards         132        Dallas Mavericks
# 60  48919 2019-03-10        Orlando Magic          97       Memphis Grizzlies
# 62  48925 2019-03-11   Washington Wizards         121        Sacramento Kings
# 63  48921 2019-03-10      New York Knicks          92  Minnesota Timberwolves
# 64  48932 2019-03-12        Chicago Bulls         107      Los Angeles Lakers
#
#     West_Score  West_Minus_East
# 1          123               11
# 2          110               -7
# 4          102                6
# 12         120              -23
# 16         120                2
# 20         113               -4
# 27          88              -30
# 33         110              -12
# 35         107               -5
# 38         101              -11
# 42         118                5
# 44         110               -1
# 48         115               -7
# 51          88              -39
# 52          95              -33
# 54         123               -9
# 60         105                8
# 62         115               -6
# 63         103               11
# 64         123               16

# %%
sns.distplot(game_data['West_Minus_East'])

# %%
sns.scatterplot(data=game_data_reshaped, x='East_Score', y='West_Score')

# %%
sns.regplot(data=game_data_reshaped, x='East_Score', y='West_Score')

# %% [markdown]
# ## Create regression function

# %%
X = game_data_reshaped['East_Score']
y = game_data_reshaped['West_Score']
X = sm.add_constant(X)
mod = sm.OLS(y, X, hasconst= True)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             West_Score   R-squared:                       0.090
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     34.34
# Date:                Mon, 07 Oct 2019   Prob (F-statistic):           1.07e-08
# Time:                        11:59:03   Log-Likelihood:                -1355.8
# No. Observations:                 351   AIC:                             2716.
# Df Residuals:                     349   BIC:                             2723.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.8980      5.520     14.655      0.000      70.041      91.755
# East_Score     0.2921      0.050      5.860      0.000       0.194       0.390
# ==============================================================================
# Omnibus:                        0.506   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.777   Jarque-Bera (JB):                0.297
# Skew:                           0.012   Prob(JB):                        0.862
# Kurtosis:                       3.141   Cond. No.                         992.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
