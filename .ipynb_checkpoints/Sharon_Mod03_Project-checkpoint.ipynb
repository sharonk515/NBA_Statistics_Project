# %%
import requests
import json
import pandas as pd
import numpy as np
import math

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import statsmodels.api as sm
from scipy.stats import stats

import time

# %% [markdown]
# # Games Data

# %% [markdown]
# ## Creating function to request data

# %%
def get_games_data(page=1, per_page=100, total_pages=None):
    
    # Get number of pages
    url = 'https://www.balldontlie.io/api/v1/games'
    parameters = {'per_page': per_page, 'page': page}
    
    
    resp = requests.get(url, params=parameters).json()
    total_pages = min(x for x in [resp['meta']['total_pages'], total_pages] if x is not None)
    
    # Initialize data frame
    games_data = pd.DataFrame()
        
    for page_num in range(page, total_pages+1):
                
        # Make request
        parameters = {'page': page_num, 'per_page': per_page}
        
        resp = requests.get(url, params=parameters).json()
        
        # Create dataframe from json data key
        data = pd.DataFrame.from_records(resp['data'])    
        
        # Format date column to date column
        data['date'] = pd.to_datetime(data['date'], yearfirst=True, errors='coerce').dt.tz_localize(None)
        
        # Creating columns out of the dictionary-type columns
        for col in data.columns:
            if type(data[col][0]) == dict:
                for k in data[col][0].keys():
                    data[col+"_"+k] = data[col].apply(lambda x: x[k])
                    
        # Create a page column
        data['page'] = page_num
        
        # Concat data frames
        games_data = pd.concat([games_data, data])
        
        # Delay next request
        time.sleep(.8)
    
    
    return games_data

# %%
games_data = get_games_data()

# %%
games_data.to_csv('games_data.csv', index=False)

# %%
games_data = pd.read_csv('games_data.csv')

# %%
games_data.head()
# Out:
#          date                                          home_team  \
# 0  2019-01-30  {'id': 2, 'abbreviation': 'BOS', 'city': 'Bost...
# 1  2019-02-09  {'id': 2, 'abbreviation': 'BOS', 'city': 'Bost...
# 2  2019-02-08  {'id': 23, 'abbreviation': 'PHI', 'city': 'Phi...
# 3  2019-02-08  {'id': 30, 'abbreviation': 'WAS', 'city': 'Was...
# 4  2019-02-08  {'id': 26, 'abbreviation': 'SAC', 'city': 'Sac...
#
#    home_team_score     id  period  postseason  season status   time  \
# 0              126  47179       4       False    2018  Final
# 1              112  48751       4       False    2018  Final
# 2              117  48739       4       False    2018  Final
# 3              119  48740       4       False    2018  Final
# 4              102  48746       4       False    2018  Final
#
#                                         visitor_team  ...  \
# 0  {'id': 4, 'abbreviation': 'CHA', 'city': 'Char...  ...
# 1  {'id': 13, 'abbreviation': 'LAC', 'city': 'LA'...  ...
# ...

# %%
games_data["postseason"].value_counts()
# Out:
# False    44551
# True      2974
# Name: postseason, dtype: int64

# %% [markdown]
# # Hypothesis 1: West_Score = B0 + B1 East_Score

# %% [markdown]
# ## Creating function to shape dataframe

# %% [markdown]
# id, East Score, West Score

# %%
def games_data_east_west(data):
    
    # Filter to only include games where East plays West team
    data = data.loc[((data['home_team_conference']=="East")
                     &(data['visitor_team_conference']=="West")) 
                    | ((data['home_team_conference']=="West")
                       &(data['visitor_team_conference']=="East"))].copy()

    # Creating East columns
    data['east_team'] = np.where(data['home_team_conference']=="East",
                                 data['home_team_full_name'],
                                 data['visitor_team_full_name'])
    data['east_score'] = np.where(data['home_team_conference']=="East",
                                  data['home_team_score'], 
                                  data['visitor_team_score'])
    
    # Creating West columns
    data['west_team'] = np.where(data['home_team_conference']=="West",
                                 data['home_team_full_name'],
                                 data['visitor_team_full_name'])
    data['west_score'] = np.where(data['home_team_conference']=="West",
                                  data['home_team_score'],
                                  data['visitor_team_score'])
    
    
    data['west_minus_east'] = data['west_score'] - data['east_score']
    data['division_winner'] = np.where(data['west_score'] > data['east_score'],"West","East")
    
    data = data[['id', 'date', 'season', 'east_team',
                 'east_score', 'west_team', 'west_score',
                 'west_minus_east', 'division_winner', 'postseason']]

    return data

# %%
games_data_east_west = games_data_east_west(games_data)

# %%
games_data_east_west.head()
# Out:
#        id        date  season           east_team  east_score  \
# 1   48751  2019-02-09    2018      Boston Celtics         112
# 2   48739  2019-02-08    2018  Philadelphia 76ers         117
# 4   48746  2019-02-08    2018          Miami Heat          96
# 12  48760  2019-02-10    2018  Philadelphia 76ers         143
# 16  48759  2019-02-10    2018          Miami Heat         118
#
#                 west_team  west_score  west_minus_east division_winner  \
# 1             LA Clippers         123               11            West
# 2          Denver Nuggets         110               -7            East
# 4        Sacramento Kings         102                6            West
# 12     Los Angeles Lakers         120              -23            East
# 16  Golden State Warriors         120                2            West
#
#     postseason
# 1        False
# 2        False
# 4        False
# 12       False
# 16       False

# %%
games_data_east_west.boxplot(["east_score", "west_score"]);

# %%
stats.ttest_rel(games_data_east_west["west_score"], games_data_east_west["east_score"])
# Out:
# Ttest_relResult(statistic=8.562278581075956, pvalue=1.2099786870806181e-17)

# %%
diff_mean = games_data_east_west["west_minus_east"].mean()
diff_sd = games_data_east_west["west_minus_east"].std()
t = round(stats.ttest_rel(games_data_east_west["west_score"], games_data_east_west["east_score"])[0], 4)
n = len(games_data_east_west["west_minus_east"])
lower = diff_mean - t*(diff_sd / n)
upper = diff_mean + t*(diff_sd / n)
lower, upper
# Out:
# (0.9240656647698451, 0.9390778786957135)

# %%
playoffs_data_east_west = games_data_east_west.loc[games_data_east_west["postseason"]==True]
playoffs_data_east_west.head()
# Out:
#          id        date  season      east_team  east_score  \
# 44625  1740  1992-06-03    1991  Chicago Bulls         122
# 44626  1741  1992-06-05    1991  Chicago Bulls         104
# 44627  1742  1992-06-07    1991  Chicago Bulls          94
# 44628  1743  1992-06-10    1991  Chicago Bulls          88
# 44629  1744  1992-06-12    1991  Chicago Bulls         119
#
#                     west_team  west_score  west_minus_east division_winner  \
# 44625  Portland Trail Blazers          89              -33            East
# 44626  Portland Trail Blazers         115               11            West
# 44627  Portland Trail Blazers          84              -10            East
# 44628  Portland Trail Blazers          93                5            West
# 44629  Portland Trail Blazers         106              -13            East
#
#        postseason
# 44625        True
# 44626        True
# 44627        True
# 44628        True
# 44629        True

# %%
playoffs_data_east_west.boxplot(["east_score", "west_score"]);

# %%
stats.ttest_rel(playoffs_data_east_west["west_score"], playoffs_data_east_west["east_score"])
# Out:
# Ttest_relResult(statistic=-0.4981434564959921, pvalue=0.6188226223515709)

# %%
diff_mean = playoffs_data_east_west["west_minus_east"].mean()
diff_sd = playoffs_data_east_west["west_minus_east"].std()
t = round(stats.ttest_rel(playoffs_data_east_west["west_score"], playoffs_data_east_west["east_score"])[0], 4)
n = len(playoffs_data_east_west["west_minus_east"])
lower = diff_mean - t*(diff_sd / n)
upper = diff_mean + t*(diff_sd / n)
lower, upper
# Out:
# (-0.3896921450836041, -0.44230785491639585)

# %%
west_wins = pd.DataFrame(games_data_east_west.loc[games_data_east_west["division_winner"]
                                                  == "West"].groupby("season")["id"].count())
east_wins = pd.DataFrame(games_data_east_west.loc[games_data_east_west["division_winner"]
                                                  == "East"].groupby("season")["id"].count())
division_wins = pd.merge(west_wins, east_wins, on="season", suffixes=('_west', '_east'))
division_wins.columns = ["west_wins", "east_wins"]
division_wins.head()
# Out:
#         west_wins  east_wins
# season
# 1979          204        199
# 1980          120        150
# 1981          124        146
# 1982          126        142
# 1983          126        145

# %%
sns.scatterplot(data=division_wins, x="west_wins", y="east_wins");

# %%
print(stats.normaltest(division_wins["west_wins"]))
sns.distplot(division_wins["west_wins"]);
# Out:
# NormaltestResult(statistic=3.637032070836699, pvalue=0.16226636990043733)

# %%
print(stats.normaltest(division_wins["east_wins"]))
sns.distplot(division_wins["east_wins"]);
# Out:
# NormaltestResult(statistic=14.618046762619265, pvalue=0.0006694705503626533)

# %%
sns.distplot(games_data_east_west['west_minus_east']);

# %%
sns.scatterplot(data=games_data_east_west, x='east_score', y='west_score', hue='postseason');

# %%
sns.regplot(data=games_data_east_west, x='east_score', y='west_score');

# %% [markdown]
# ## Create regression function

# %%
X = division_wins['east_wins']
y = division_wins['west_wins']
X = sm.add_constant(X)
mod = sm.OLS(y, X, hasconst= True)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              west_wins   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     24.14
# Date:                Tue, 08 Oct 2019   Prob (F-statistic):           1.74e-05
# Time:                        14:12:47   Log-Likelihood:                -210.26
# No. Observations:                  40   AIC:                             424.5
# Df Residuals:                      38   BIC:                             427.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.7942     38.343      0.542      0.591     -56.828      98.417
# ...

# %%
X = games_data_reshaped['east_score']
y = games_data_reshaped['west_score']
X = sm.add_constant(X)
mod = sm.OLS(y, X, hasconst= True)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             west_score   R-squared:                       0.233
# Model:                            OLS   Adj. R-squared:                  0.233
# Method:                 Least Squares   F-statistic:                     4679.
# Date:                Mon, 07 Oct 2019   Prob (F-statistic):               0.00
# Time:                        20:56:11   Log-Likelihood:                -59626.
# No. Observations:               15403   AIC:                         1.193e+05
# Df Residuals:                   15401   BIC:                         1.193e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         53.4712      0.720     74.277      0.000      52.060      54.882
# ...

# %% [markdown]
# # Hypothesis 2: No Team has Better Home Court Advantage

# %%
def games_data_home(data):
    
    data['home_win'] = (data['home_team_score'] > data['visitor_team_score'])*1
    
    data['home_score_diff'] = data['home_team_score'] - data['visitor_team_score']
    
    data = data[['id', 'home_team_full_name', 'home_team_score', 'home_score_diff', 'home_win', 'home_team_conference']]
    return data

# %%
games_data_home = games_data_home(games_data)

# %%
games_data_home.head()
# Out:
#       id home_team_full_name  home_team_score  home_score_diff  home_win  \
# 0  47179      Boston Celtics              126               32         1
# 1  48751      Boston Celtics              112              -11         0
# 2  48739  Philadelphia 76ers              117                7         1
# 3  48740  Washington Wizards              119               13         1
# 4  48746    Sacramento Kings              102                6         1
#
#   home_team_conference
# 0                 East
# 1                 East
# 2                 East
# 3                 East
# 4                 West

# %%
east_teams_home = games_data_home.loc[games_data_home["home_team_conference"] == "East"]
east_teams_home
# Out:
#           id  home_team_full_name  home_team_score  home_score_diff  home_win  \
# 0      47179       Boston Celtics              126               32         1
# 1      48751       Boston Celtics              112              -11         0
# 2      48739   Philadelphia 76ers              117                7         1
# 3      48740   Washington Wizards              119               13         1
# 5      48762      Detroit Pistons              121                9         1
# 7      48748       Indiana Pacers              105               15         1
# 8      48749        Atlanta Hawks              120               -9         0
# 10     48752        Chicago Bulls              125               -9         0
# 12     48760   Philadelphia 76ers              143               23         1
# 14     48755      Milwaukee Bucks               83              -20         0
# 17     48758        Atlanta Hawks              108              -16         0
# ...

# %%
teams = sorted(east_teams_home["home_team_full_name"].unique())
east_home_games = pd.DataFrame(teams, columns=["team"])
east_home_games["score_diff_mean"] = east_teams_home.groupby("home_team_full_name")["home_score_diff"].mean().values
east_home_games = east_home_games.sort_values(by=["score_diff_mean"], ascending=False)
east_home_games['team_names'] = east_home_games["team"].apply(lambda x: x.lower().replace(" ", "_"))
east_home_games
# Out:
#                    team  score_diff_mean           team_names
# 1        Boston Celtics         5.417540       boston_celtics
# 7        Indiana Pacers         4.639515       indiana_pacers
# 6       Detroit Pistons         3.935006      detroit_pistons
# 9       Milwaukee Bucks         3.683284      milwaukee_bucks
# 4         Chicago Bulls         3.678389        chicago_bulls
# 8            Miami Heat         3.636364           miami_heat
# 5   Cleveland Cavaliers         3.472093  cleveland_cavaliers
# 0         Atlanta Hawks         3.150701        atlanta_hawks
# 11        Orlando Magic         3.114961        orlando_magic
# 12   Philadelphia 76ers         2.288351   philadelphia_76ers
# 10      New York Knicks         2.236152      new_york_knicks
# 13      Toronto Raptors         2.059289      toronto_raptors
# 14   Washington Wizards         1.562575   washington_wizards
# 3     Charlotte Hornets         1.270134    charlotte_hornets
# ...

# %%
east_teams = list(east_home_games.iloc[:5]["team_names"])
east_teams
# Out:
# ['boston_celtics',
#  'indiana_pacers',
#  'detroit_pistons',
#  'milwaukee_bucks',
#  'chicago_bulls']

# %%
west_teams_home = games_data_home.loc[games_data_home["home_team_conference"] == "West"]
west_teams_home
# Out:
#           id     home_team_full_name  home_team_score  home_score_diff  \
# 4      48746        Sacramento Kings              102                6
# 6      48745    New Orleans Pelicans              122                5
# 9      48747               Utah Jazz              125               20
# 11     48756        Dallas Mavericks              102                1
# 13     48757        Sacramento Kings              117               13
# 15     48754         Houston Rockets              112               -5
# 16     48759   Golden State Warriors              120                2
# 18     48766         Houston Rockets              120               16
# 23     48774   Golden State Warriors              115                7
# 24     48772       Memphis Grizzlies              107               -1
# 27     48773    New Orleans Pelicans               88              -30
# 28     48781  Minnesota Timberwolves              121               10
# ...

# %%
teams = sorted(west_teams_home["home_team_full_name"].unique())
west_home_games = pd.DataFrame(teams, columns=["team"])
west_home_games["score_diff_mean"] = west_teams_home.groupby("home_team_full_name")["home_score_diff"].mean().values
west_home_games = west_home_games.sort_values(by=["score_diff_mean"], ascending=False)
west_home_games['team_names'] = west_home_games["team"].apply(lambda x: x.lower().replace(" ", "_"))
west_home_games
# Out:
#                       team  score_diff_mean              team_names
# 13       San Antonio Spurs         7.584488       san_antonio_spurs
# 14               Utah Jazz         6.465714               utah_jazz
# 5       Los Angeles Lakers         6.198374      los_angeles_lakers
# 9    Oklahoma City Thunder         6.101540   oklahoma_city_thunder
# 11  Portland Trail Blazers         5.883372  portland_trail_blazers
# 10            Phoenix Suns         5.093426            phoenix_suns
# 3          Houston Rockets         4.957883         houston_rockets
# 1           Denver Nuggets         4.078199          denver_nuggets
# 2    Golden State Warriors         3.278824   golden_state_warriors
# 0         Dallas Mavericks         2.943080        dallas_mavericks
# 12        Sacramento Kings         2.018663        sacramento_kings
# 8     New Orleans Pelicans         1.436185    new_orleans_pelicans
# 4              LA Clippers         0.448463             la_clippers
# ...

# %%
west_teams = list(west_home_games.iloc[:5]["team"])
west_teams
# Out:
# ['San Antonio Spurs',
#  'Utah Jazz',
#  'Los Angeles Lakers',
#  'Oklahoma City Thunder',
#  'Portland Trail Blazers']

# %%
import statsmodels.formula.api as smf

# %%
teams = sorted(games_data_home["home_team_full_name"].unique())
home_games = pd.DataFrame(teams, columns=["team"])
home_games["home_score_diff_mean"] = games_data_home.groupby("home_team_full_name")["home_score_diff"].mean().values
# home_games["win_pct"] = (games_data_home.groupby("home_team_full_name")["home_win"].sum().values
#                         / games_data_home.groupby("home_team_full_name")["id"].count().values)
home_games = home_games.sort_values(by=["home_score_diff_mean"], ascending=False)
home_games
# Out:
#                       team  home_score_diff_mean
# 26       San Antonio Spurs              7.584488
# 28               Utah Jazz              6.465714
# 13      Los Angeles Lakers              6.198374
# 20   Oklahoma City Thunder              6.101540
# 24  Portland Trail Blazers              5.883372
# 1           Boston Celtics              5.417540
# 23            Phoenix Suns              5.093426
# 10         Houston Rockets              4.957883
# 11          Indiana Pacers              4.639515
# 7           Denver Nuggets              4.078199
# 8          Detroit Pistons              3.935006
# 16         Milwaukee Bucks              3.683284
# 4            Chicago Bulls              3.678389
# 15              Miami Heat              3.636364
# 5      Cleveland Cavaliers              3.472093
# 9    Golden State Warriors              3.278824
# 0            Atlanta Hawks              3.150701
# 21           Orlando Magic              3.114961
# ...

# %%
import itertools

# %%
east = list(itertools.combinations(east_teams, 2))

# %%
west = list(itertools.combinations(west_teams, 2))
