# %% [markdown]
# ## Import Packages

# %%
import requests
import json
import pandas as pd
import numpy as np
import math
import itertools

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import statsmodels.api as sm
import scipy.stats as stats
import statsmodels.formula.api as smf

import time

import data_prep as dp
import hypothesis_tests as tests
import visualizations as v

# %% [markdown]
# # Games Data

# %% [markdown]
# ## Request data

# %%
url = 'https://www.balldontlie.io/api/v1/games'
games_data = dp.get_data(url)

# %%
games_data = pd.read_csv('data/games_data.csv')

# %%
games_data
# Out:
#             date                                          home_team  \
# 0     1996-04-26  {'id': 5, 'abbreviation': 'CHI', 'city': 'Chic...
# 1     1996-04-27  {'id': 29, 'abbreviation': 'UTA', 'city': 'Uta...
# 2     1996-04-28  {'id': 22, 'abbreviation': 'ORL', 'city': 'Orl...
# 3     1996-04-30  {'id': 26, 'abbreviation': 'SAC', 'city': 'Sac...
# 4     1996-05-01  {'id': 20, 'abbreviation': 'NYK', 'city': 'New...
# 5     1996-05-02  {'id': 26, 'abbreviation': 'SAC', 'city': 'Sac...
# 6     1996-05-03  {'id': 24, 'abbreviation': 'PHX', 'city': 'Pho...
# 7     1996-05-04  {'id': 21, 'abbreviation': 'OKC', 'city': 'Okl...
# 8     1996-05-05  {'id': 5, 'abbreviation': 'CHI', 'city': 'Chic...
# 9     1992-04-23  {'id': 6, 'abbreviation': 'CLE', 'city': 'Clev...
# 10    1992-04-24  {'id': 24, 'abbreviation': 'PHX', 'city': 'Pho...
# 11    1992-04-25  {'id': 2, 'abbreviation': 'BOS', 'city': 'Bost...
# 12    1992-04-26  {'id': 29, 'abbreviation': 'UTA', 'city': 'Uta...
# 13    1992-04-27  {'id': 12, 'abbreviation': 'IND', 'city': 'Ind...
# 14    1992-04-28  {'id': 21, 'abbreviation': 'OKC', 'city': 'Okl...
# 15    1996-04-26  {'id': 21, 'abbreviation': 'OKC', 'city': 'Okl...
# 16    1996-04-27  {'id': 14, 'abbreviation': 'LAL', 'city': 'Los...
# 17    1996-04-28  {'id': 27, 'abbreviation': 'SAS', 'city': 'San...
# 18    1996-05-01  {'id': 16, 'abbreviation': 'MIA', 'city': 'Mia...
# 19    1997-04-24  {'id': 20, 'abbreviation': 'NYK', 'city': 'New...
# 20    1997-04-25  {'id': 5, 'abbreviation': 'CHI', 'city': 'Chic...
# 21    1997-04-26  {'id': 29, 'abbreviation': 'UTA', 'city': 'Uta...
# 22    1997-04-27  {'id': 14, 'abbreviation': 'LAL', 'city': 'Los...
# 23    1997-04-29  {'id': 24, 'abbreviation': 'PHX', 'city': 'Pho...
# 24    1997-04-30  {'id': 30, 'abbreviation': 'WAS', 'city': 'Was...
# 25    1997-05-01  {'id': 24, 'abbreviation': 'PHX', 'city': 'Pho...
# 26    1997-05-02  {'id': 9, 'abbreviation': 'DET', 'city': 'Detr...
# 27    1997-05-04  {'id': 1, 'abbreviation': 'ATL', 'city': 'Atla...
# 28    1992-04-23  {'id': 25, 'abbreviation': 'POR', 'city': 'Por...
# 29    1992-04-24  {'id': 20, 'abbreviation': 'NYK', 'city': 'New...
# ...          ...                                                ...
# 2944  2019-04-28  {'id': 17, 'abbreviation': 'MIL', 'city': 'Mil...
# 2945  2019-04-29  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...
# 2946  2019-04-30  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...
# 2947  2019-04-30  {'id': 17, 'abbreviation': 'MIL', 'city': 'Mil...
# 2948  2019-05-02  {'id': 23, 'abbreviation': 'PHI', 'city': 'Phi...
# 2949  2019-05-03  {'id': 2, 'abbreviation': 'BOS', 'city': 'Bost...
# 2950  2019-05-04  {'id': 11, 'abbreviation': 'HOU', 'city': 'Hou...
# 2951  2019-05-01  {'id': 8, 'abbreviation': 'DEN', 'city': 'Denv...
# 2952  2019-05-03  {'id': 25, 'abbreviation': 'POR', 'city': 'Por...
# 2953  2019-05-21  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...
# 2954  2019-05-17  {'id': 17, 'abbreviation': 'MIL', 'city': 'Mil...
# 2955  2019-05-05  {'id': 25, 'abbreviation': 'POR', 'city': 'Por...
# 2956  2019-05-12  {'id': 8, 'abbreviation': 'DEN', 'city': 'Denv...
# 2957  2019-05-12  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...
# 2958  2019-05-07  {'id': 8, 'abbreviation': 'DEN', 'city': 'Denv...
# 2959  2019-05-23  {'id': 17, 'abbreviation': 'MIL', 'city': 'Mil...
# 2960  2019-05-25  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...
# 2961  2019-05-18  {'id': 25, 'abbreviation': 'POR', 'city': 'Por...
# 2962  2019-06-07  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...
# 2963  2019-05-09  {'id': 25, 'abbreviation': 'POR', 'city': 'Por...
# 2964  2019-05-14  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...
# 2965  2019-05-30  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...
# 2966  2019-06-10  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...
# 2967  2019-05-15  {'id': 17, 'abbreviation': 'MIL', 'city': 'Mil...
# 2968  2019-05-19  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...
# 2969  2019-06-02  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...
# 2970  2019-05-20  {'id': 25, 'abbreviation': 'POR', 'city': 'Por...
# 2971  2019-05-16  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...
# 2972  2019-06-13  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...
# 2973  2019-06-05  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...
#
#       home_team_score     id  period  postseason  season status   time  \
# 0                 102   1218       4        True    1995  Final
# 1                 105   1219       4        True    1995  Final
# 2                  92   1220       4        True    1995  Final
# 3                  89   1221       4        True    1995  Final
# 4                  81   1222       4        True    1995  Final
# 5                  87   1223       4        True    1995  Final
# 6                  98   1224       4        True    1995  Final
# 7                 108   1225       4        True    1995  Final
# 8                  91   1226       4        True    1995  Final
# 9                 120   1332       4        True    1991  Final
# 10                117   1333       4        True    1991  Final
# 11                119   1334       4        True    1991  Final
# 12                103   1335       4        True    1991  Final
# 13                 98   1336       4        True    1991  Final
# 14                129   1337       4        True    1991  Final
# 15                 97   1377       4        True    1995  Final
# 16                104   1378       4        True    1995  Final
# 17                110   1379       4        True    1995  Final
# 18                 91   1380       4        True    1995  Final
# 19                109   1405       4        True    1996  Final
# 20                 98   1406       4        True    1996  Final
# 21                105   1407       4        True    1996  Final
# 22                107   1408       4        True    1996  Final
# 23                110   1409       4        True    1996  Final
# 24                 95   1410       4        True    1996  Final
# 25                115   1411       4        True    1996  Final
# 26                 82   1412       4        True    1996  Final
# 27                 84   1413       4        True    1996  Final
# 28                115   1464       4        True    1991  Final
# 29                109   1465       4        True    1991  Final
# ...               ...    ...     ...         ...     ...    ...    ...
# 2944               90  61725       4        True    2018  Final
# 2945               89  61726       4        True    2018  Final
# 2946              115  61727       4        True    2018  Final
# 2947              123  61728       4        True    2018  Final
# 2948              116  61736       4        True    2018  Final
# 2949              116  61737       4        True    2018  Final
# 2950              126  61738       5        True    2018  Final
# 2951               90  61848       4        True    2018  Final
# 2952              140  61851       8        True    2018  Final
# 2953              120  62351       4        True    2018  Final
# 2954              125  62347       4        True    2018  Final
# 2955              112  61854       4        True    2018  Final
# 2956               96  61867       4        True    2018  Final
# 2957               92  61749       4        True    2018  Final
# 2958              124  61858       4        True    2018  Final
# 2959               99  62353       4        True    2018  Final
# 2960              100  62355       4        True    2018  Final
# 2961               99  62348       4        True    2018  Final
# 2962               92  62483       4        True    2018  Final
# 2963              119  61861       4        True    2018  Final
# 2964              116  62344       4        True    2018  Final
# 2965              118  62480       4        True    2018  Final
# 2966              105  62484       4        True    2018  Final
# 2967              108  62345       4        True    2018  Final
# 2968              118  62349       6        True    2018  Final
# 2969              104  62481       4        True    2018  Final
# 2970              117  62350       5        True    2018  Final
# 2971              114  62346       4        True    2018  Final
# 2972              110  62485       4        True    2018  Final
# 2973              109  62482       4        True    2018  Final
#
#                                            visitor_team  ...  \
# 0     {'id': 16, 'abbreviation': 'MIA', 'city': 'Mia...  ...
# 1     {'id': 25, 'abbreviation': 'POR', 'city': 'Por...  ...
# 2     {'id': 9, 'abbreviation': 'DET', 'city': 'Detr...  ...
# 3     {'id': 21, 'abbreviation': 'OKC', 'city': 'Okl...  ...
# 4     {'id': 6, 'abbreviation': 'CLE', 'city': 'Clev...  ...
# 5     {'id': 21, 'abbreviation': 'OKC', 'city': 'Okl...  ...
# 6     {'id': 27, 'abbreviation': 'SAS', 'city': 'San...  ...
# 7     {'id': 11, 'abbreviation': 'HOU', 'city': 'Hou...  ...
# 8     {'id': 20, 'abbreviation': 'NYK', 'city': 'New...  ...
# 9     {'id': 3, 'abbreviation': 'BKN', 'city': 'Broo...  ...
# 10    {'id': 27, 'abbreviation': 'SAS', 'city': 'San...  ...
# 11    {'id': 12, 'abbreviation': 'IND', 'city': 'Ind...  ...
# 12    {'id': 13, 'abbreviation': 'LAC', 'city': 'LA'...  ...
# 13    {'id': 2, 'abbreviation': 'BOS', 'city': 'Bost...  ...
# 14    {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...  ...
# 15    {'id': 26, 'abbreviation': 'SAC', 'city': 'Sac...  ...
# 16    {'id': 11, 'abbreviation': 'HOU', 'city': 'Hou...  ...
# 17    {'id': 24, 'abbreviation': 'PHX', 'city': 'Pho...  ...
# 18    {'id': 5, 'abbreviation': 'CHI', 'city': 'Chic...  ...
# 19    {'id': 4, 'abbreviation': 'CHA', 'city': 'Char...  ...
# 20    {'id': 30, 'abbreviation': 'WAS', 'city': 'Was...  ...
# 21    {'id': 13, 'abbreviation': 'LAC', 'city': 'LA'...  ...
# 22    {'id': 25, 'abbreviation': 'POR', 'city': 'Por...  ...
# 23    {'id': 21, 'abbreviation': 'OKC', 'city': 'Okl...  ...
# 24    {'id': 5, 'abbreviation': 'CHI', 'city': 'Chic...  ...
# 25    {'id': 21, 'abbreviation': 'OKC', 'city': 'Okl...  ...
# 26    {'id': 1, 'abbreviation': 'ATL', 'city': 'Atla...  ...
# 27    {'id': 9, 'abbreviation': 'DET', 'city': 'Detr...  ...
# 28    {'id': 14, 'abbreviation': 'LAL', 'city': 'Los...  ...
# 29    {'id': 9, 'abbreviation': 'DET', 'city': 'Detr...  ...
# ...                                                 ...  ...
# 2944  {'id': 2, 'abbreviation': 'BOS', 'city': 'Bost...  ...
# 2945  {'id': 23, 'abbreviation': 'PHI', 'city': 'Phi...  ...
# 2946  {'id': 11, 'abbreviation': 'HOU', 'city': 'Hou...  ...
# 2947  {'id': 2, 'abbreviation': 'BOS', 'city': 'Bost...  ...
# 2948  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...  ...
# 2949  {'id': 17, 'abbreviation': 'MIL', 'city': 'Mil...  ...
# 2950  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...  ...
# 2951  {'id': 25, 'abbreviation': 'POR', 'city': 'Por...  ...
# 2952  {'id': 8, 'abbreviation': 'DEN', 'city': 'Denv...  ...
# 2953  {'id': 17, 'abbreviation': 'MIL', 'city': 'Mil...  ...
# 2954  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...  ...
# 2955  {'id': 8, 'abbreviation': 'DEN', 'city': 'Denv...  ...
# 2956  {'id': 25, 'abbreviation': 'POR', 'city': 'Por...  ...
# 2957  {'id': 23, 'abbreviation': 'PHI', 'city': 'Phi...  ...
# 2958  {'id': 25, 'abbreviation': 'POR', 'city': 'Por...  ...
# 2959  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...  ...
# 2960  {'id': 17, 'abbreviation': 'MIL', 'city': 'Mil...  ...
# 2961  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...  ...
# 2962  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...  ...
# 2963  {'id': 8, 'abbreviation': 'DEN', 'city': 'Denv...  ...
# 2964  {'id': 25, 'abbreviation': 'POR', 'city': 'Por...  ...
# 2965  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...  ...
# 2966  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...  ...
# 2967  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...  ...
# 2968  {'id': 17, 'abbreviation': 'MIL', 'city': 'Mil...  ...
# 2969  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...  ...
# 2970  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...  ...
# 2971  {'id': 25, 'abbreviation': 'POR', 'city': 'Por...  ...
# 2972  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...  ...
# 2973  {'id': 28, 'abbreviation': 'TOR', 'city': 'Tor...  ...
#
#       home_team_division     home_team_full_name home_team_name  \
# 0                Central           Chicago Bulls          Bulls
# 1              Northwest               Utah Jazz           Jazz
# 2              Southeast           Orlando Magic          Magic
# 3                Pacific        Sacramento Kings          Kings
# 4               Atlantic         New York Knicks         Knicks
# 5                Pacific        Sacramento Kings          Kings
# 6                Pacific            Phoenix Suns           Suns
# 7              Northwest   Oklahoma City Thunder        Thunder
# 8                Central           Chicago Bulls          Bulls
# 9                Central     Cleveland Cavaliers      Cavaliers
# 10               Pacific            Phoenix Suns           Suns
# 11              Atlantic          Boston Celtics        Celtics
# 12             Northwest               Utah Jazz           Jazz
# 13               Central          Indiana Pacers         Pacers
# 14             Northwest   Oklahoma City Thunder        Thunder
# 15             Northwest   Oklahoma City Thunder        Thunder
# 16               Pacific      Los Angeles Lakers         Lakers
# 17             Southwest       San Antonio Spurs          Spurs
# 18             Southeast              Miami Heat           Heat
# 19              Atlantic         New York Knicks         Knicks
# 20               Central           Chicago Bulls          Bulls
# 21             Northwest               Utah Jazz           Jazz
# 22               Pacific      Los Angeles Lakers         Lakers
# 23               Pacific            Phoenix Suns           Suns
# 24             Southeast      Washington Wizards        Wizards
# 25               Pacific            Phoenix Suns           Suns
# 26               Central         Detroit Pistons        Pistons
# 27             Southeast           Atlanta Hawks          Hawks
# 28             Northwest  Portland Trail Blazers  Trail Blazers
# 29              Atlantic         New York Knicks         Knicks
# ...                  ...                     ...            ...
# 2944             Central         Milwaukee Bucks          Bucks
# 2945            Atlantic         Toronto Raptors        Raptors
# 2946             Pacific   Golden State Warriors       Warriors
# 2947             Central         Milwaukee Bucks          Bucks
# 2948            Atlantic      Philadelphia 76ers          76ers
# 2949            Atlantic          Boston Celtics        Celtics
# 2950           Southwest         Houston Rockets        Rockets
# 2951           Northwest          Denver Nuggets        Nuggets
# 2952           Northwest  Portland Trail Blazers  Trail Blazers
# 2953            Atlantic         Toronto Raptors        Raptors
# 2954             Central         Milwaukee Bucks          Bucks
# 2955           Northwest  Portland Trail Blazers  Trail Blazers
# 2956           Northwest          Denver Nuggets        Nuggets
# 2957            Atlantic         Toronto Raptors        Raptors
# 2958           Northwest          Denver Nuggets        Nuggets
# 2959             Central         Milwaukee Bucks          Bucks
# 2960            Atlantic         Toronto Raptors        Raptors
# 2961           Northwest  Portland Trail Blazers  Trail Blazers
# 2962             Pacific   Golden State Warriors       Warriors
# 2963           Northwest  Portland Trail Blazers  Trail Blazers
# 2964             Pacific   Golden State Warriors       Warriors
# 2965            Atlantic         Toronto Raptors        Raptors
# 2966            Atlantic         Toronto Raptors        Raptors
# 2967             Central         Milwaukee Bucks          Bucks
# 2968            Atlantic         Toronto Raptors        Raptors
# 2969            Atlantic         Toronto Raptors        Raptors
# 2970           Northwest  Portland Trail Blazers  Trail Blazers
# 2971             Pacific   Golden State Warriors       Warriors
# 2972             Pacific   Golden State Warriors       Warriors
# 2973             Pacific   Golden State Warriors       Warriors
#
#      visitor_team_id visitor_team_abbreviation visitor_team_city  \
# 0                 16                       MIA             Miami
# 1                 25                       POR          Portland
# 2                  9                       DET           Detroit
# 3                 21                       OKC     Oklahoma City
# 4                  6                       CLE         Cleveland
# 5                 21                       OKC     Oklahoma City
# 6                 27                       SAS       San Antonio
# 7                 11                       HOU           Houston
# 8                 20                       NYK          New York
# 9                  3                       BKN          Brooklyn
# 10                27                       SAS       San Antonio
# 11                12                       IND           Indiana
# 12                13                       LAC                LA
# 13                 2                       BOS            Boston
# 14                10                       GSW      Golden State
# 15                26                       SAC        Sacramento
# 16                11                       HOU           Houston
# 17                24                       PHX           Phoenix
# 18                 5                       CHI           Chicago
# 19                 4                       CHA         Charlotte
# 20                30                       WAS        Washington
# 21                13                       LAC                LA
# 22                25                       POR          Portland
# 23                21                       OKC     Oklahoma City
# 24                 5                       CHI           Chicago
# 25                21                       OKC     Oklahoma City
# 26                 1                       ATL           Atlanta
# 27                 9                       DET           Detroit
# 28                14                       LAL       Los Angeles
# 29                 9                       DET           Detroit
# ...              ...                       ...               ...
# 2944               2                       BOS            Boston
# 2945              23                       PHI      Philadelphia
# 2946              11                       HOU           Houston
# 2947               2                       BOS            Boston
# 2948              28                       TOR           Toronto
# 2949              17                       MIL         Milwaukee
# 2950              10                       GSW      Golden State
# 2951              25                       POR          Portland
# 2952               8                       DEN            Denver
# 2953              17                       MIL         Milwaukee
# 2954              28                       TOR           Toronto
# 2955               8                       DEN            Denver
# 2956              25                       POR          Portland
# 2957              23                       PHI      Philadelphia
# 2958              25                       POR          Portland
# 2959              28                       TOR           Toronto
# 2960              17                       MIL         Milwaukee
# 2961              10                       GSW      Golden State
# 2962              28                       TOR           Toronto
# 2963               8                       DEN            Denver
# 2964              25                       POR          Portland
# 2965              10                       GSW      Golden State
# 2966              10                       GSW      Golden State
# 2967              28                       TOR           Toronto
# 2968              17                       MIL         Milwaukee
# 2969              10                       GSW      Golden State
# 2970              10                       GSW      Golden State
# 2971              25                       POR          Portland
# 2972              28                       TOR           Toronto
# 2973              28                       TOR           Toronto
#
#      visitor_team_conference visitor_team_division  visitor_team_full_name  \
# 0                       East             Southeast              Miami Heat
# 1                       West             Northwest  Portland Trail Blazers
# 2                       East               Central         Detroit Pistons
# 3                       West             Northwest   Oklahoma City Thunder
# 4                       East               Central     Cleveland Cavaliers
# 5                       West             Northwest   Oklahoma City Thunder
# 6                       West             Southwest       San Antonio Spurs
# 7                       West             Southwest         Houston Rockets
# 8                       East              Atlantic         New York Knicks
# 9                       East              Atlantic           Brooklyn Nets
# 10                      West             Southwest       San Antonio Spurs
# 11                      East               Central          Indiana Pacers
# 12                      West               Pacific             LA Clippers
# 13                      East              Atlantic          Boston Celtics
# 14                      West               Pacific   Golden State Warriors
# 15                      West               Pacific        Sacramento Kings
# 16                      West             Southwest         Houston Rockets
# 17                      West               Pacific            Phoenix Suns
# 18                      East               Central           Chicago Bulls
# 19                      East             Southeast       Charlotte Hornets
# 20                      East             Southeast      Washington Wizards
# 21                      West               Pacific             LA Clippers
# 22                      West             Northwest  Portland Trail Blazers
# 23                      West             Northwest   Oklahoma City Thunder
# 24                      East               Central           Chicago Bulls
# 25                      West             Northwest   Oklahoma City Thunder
# 26                      East             Southeast           Atlanta Hawks
# 27                      East               Central         Detroit Pistons
# 28                      West               Pacific      Los Angeles Lakers
# 29                      East               Central         Detroit Pistons
# ...                      ...                   ...                     ...
# 2944                    East              Atlantic          Boston Celtics
# 2945                    East              Atlantic      Philadelphia 76ers
# 2946                    West             Southwest         Houston Rockets
# 2947                    East              Atlantic          Boston Celtics
# 2948                    East              Atlantic         Toronto Raptors
# 2949                    East               Central         Milwaukee Bucks
# 2950                    West               Pacific   Golden State Warriors
# 2951                    West             Northwest  Portland Trail Blazers
# 2952                    West             Northwest          Denver Nuggets
# 2953                    East               Central         Milwaukee Bucks
# 2954                    East              Atlantic         Toronto Raptors
# 2955                    West             Northwest          Denver Nuggets
# 2956                    West             Northwest  Portland Trail Blazers
# 2957                    East              Atlantic      Philadelphia 76ers
# 2958                    West             Northwest  Portland Trail Blazers
# 2959                    East              Atlantic         Toronto Raptors
# 2960                    East               Central         Milwaukee Bucks
# 2961                    West               Pacific   Golden State Warriors
# 2962                    East              Atlantic         Toronto Raptors
# 2963                    West             Northwest          Denver Nuggets
# 2964                    West             Northwest  Portland Trail Blazers
# 2965                    West               Pacific   Golden State Warriors
# 2966                    West               Pacific   Golden State Warriors
# 2967                    East              Atlantic         Toronto Raptors
# 2968                    East               Central         Milwaukee Bucks
# 2969                    West               Pacific   Golden State Warriors
# 2970                    West               Pacific   Golden State Warriors
# 2971                    West             Northwest  Portland Trail Blazers
# 2972                    East              Atlantic         Toronto Raptors
# 2973                    East              Atlantic         Toronto Raptors
#
#      visitor_team_name
# 0                 Heat
# 1        Trail Blazers
# 2              Pistons
# 3              Thunder
# 4            Cavaliers
# 5              Thunder
# 6                Spurs
# 7              Rockets
# 8               Knicks
# 9                 Nets
# 10               Spurs
# 11              Pacers
# 12            Clippers
# 13             Celtics
# 14            Warriors
# 15               Kings
# 16             Rockets
# 17                Suns
# 18               Bulls
# 19             Hornets
# 20             Wizards
# 21            Clippers
# 22       Trail Blazers
# 23             Thunder
# 24               Bulls
# 25             Thunder
# 26               Hawks
# 27             Pistons
# 28              Lakers
# 29             Pistons
# ...                ...
# 2944           Celtics
# 2945             76ers
# 2946           Rockets
# 2947           Celtics
# 2948           Raptors
# 2949             Bucks
# 2950          Warriors
# 2951     Trail Blazers
# 2952           Nuggets
# 2953             Bucks
# 2954           Raptors
# 2955           Nuggets
# 2956     Trail Blazers
# 2957             76ers
# 2958     Trail Blazers
# 2959           Raptors
# 2960             Bucks
# 2961          Warriors
# 2962           Raptors
# 2963           Nuggets
# 2964     Trail Blazers
# 2965          Warriors
# 2966          Warriors
# 2967           Raptors
# 2968             Bucks
# 2969          Warriors
# 2970          Warriors
# 2971     Trail Blazers
# 2972           Raptors
# 2973           Raptors
#
# [2974 rows x 25 columns]

# %% [markdown]
# # Hypothesis 1: East Score vs West Score

# %% [markdown]
# ## Shape dataframe for test

# %%
east_west_games = dp.make_east_west_df(games_data)

# %%
east_west_games
# Out:
#          id           east_team  east_score               west_team  \
# 101    1740       Chicago Bulls         122  Portland Trail Blazers
# 102    1741       Chicago Bulls         104  Portland Trail Blazers
# 103    1742       Chicago Bulls          94  Portland Trail Blazers
# 104    1743       Chicago Bulls          88  Portland Trail Blazers
# 105    1744       Chicago Bulls         119  Portland Trail Blazers
# 106    1745       Chicago Bulls          97  Portland Trail Blazers
# 121    1805       Chicago Bulls         107   Oklahoma City Thunder
# 122    1806       Chicago Bulls          92   Oklahoma City Thunder
# 123    1807       Chicago Bulls         108   Oklahoma City Thunder
# 124    1808       Chicago Bulls          86   Oklahoma City Thunder
# 125    1809       Chicago Bulls          78   Oklahoma City Thunder
# 126    1810       Chicago Bulls          87   Oklahoma City Thunder
# 157    2642       Chicago Bulls          84               Utah Jazz
# 158    2643       Chicago Bulls          97               Utah Jazz
# 159    2644       Chicago Bulls          93               Utah Jazz
# 160    2645       Chicago Bulls          73               Utah Jazz
# 161    2646       Chicago Bulls          90               Utah Jazz
# 162    2647       Chicago Bulls          90               Utah Jazz
# 234    3227       Chicago Bulls         100            Phoenix Suns
# 235    3228       Chicago Bulls         111            Phoenix Suns
# 236    3229       Chicago Bulls         121            Phoenix Suns
# 237    3230       Chicago Bulls         111            Phoenix Suns
# 238    3231       Chicago Bulls          98            Phoenix Suns
# 239    3232       Chicago Bulls          99            Phoenix Suns
# 304    5302     New York Knicks          78         Houston Rockets
# 305    5303     New York Knicks          91         Houston Rockets
# 306    5304     New York Knicks          89         Houston Rockets
# 307    5305     New York Knicks          91         Houston Rockets
# 308    5306     New York Knicks          91         Houston Rockets
# 309    5307     New York Knicks          84         Houston Rockets
# ...     ...                 ...         ...                     ...
# 2584  42006      Boston Celtics         117         Houston Rockets
# 2585  42007      Boston Celtics         104         Houston Rockets
# 2586  42008      Boston Celtics         106         Houston Rockets
# 2587  42009      Boston Celtics          96         Houston Rockets
# 2588  42010      Boston Celtics         114         Houston Rockets
# 2697  43446      Boston Celtics         148      Los Angeles Lakers
# 2698  43447      Boston Celtics         102      Los Angeles Lakers
# 2699  43448      Boston Celtics         111      Los Angeles Lakers
# 2700  43449      Boston Celtics         107      Los Angeles Lakers
# 2701  43450      Boston Celtics         111      Los Angeles Lakers
# 2702  43451      Boston Celtics         100      Los Angeles Lakers
# 2729  43933  Philadelphia 76ers         113      Los Angeles Lakers
# 2730  43934  Philadelphia 76ers         103      Los Angeles Lakers
# 2731  43935  Philadelphia 76ers         111      Los Angeles Lakers
# 2732  43936  Philadelphia 76ers         115      Los Angeles Lakers
# 2815  45117     Detroit Pistons         105  Portland Trail Blazers
# 2816  45118     Detroit Pistons         105  Portland Trail Blazers
# 2817  45119     Detroit Pistons         121  Portland Trail Blazers
# 2818  45120     Detroit Pistons         112  Portland Trail Blazers
# 2819  45121     Detroit Pistons          92  Portland Trail Blazers
# 2878  45795     Detroit Pistons         109      Los Angeles Lakers
# 2879  45796     Detroit Pistons         108      Los Angeles Lakers
# 2880  45797     Detroit Pistons         114      Los Angeles Lakers
# 2881  45798     Detroit Pistons         105      Los Angeles Lakers
# 2962  62483     Toronto Raptors         105   Golden State Warriors
# 2965  62480     Toronto Raptors         118   Golden State Warriors
# 2966  62484     Toronto Raptors         105   Golden State Warriors
# 2969  62481     Toronto Raptors         104   Golden State Warriors
# 2972  62485     Toronto Raptors         114   Golden State Warriors
# 2973  62482     Toronto Raptors         123   Golden State Warriors
#
#       west_score  east_minus_west
# 101           89               33
# 102          115              -11
# 103           84               10
# 104           93               -5
# 105          106               13
# 106           93                4
# 121           90               17
# 122           88                4
# 123           86               22
# 124          107              -21
# 125           89              -11
# 126           75               12
# 157           82                2
# 158           85               12
# 159          104              -11
# 160           78               -5
# 161           88                2
# 162           86                4
# 234           92                8
# 235          108                3
# 236          129               -8
# 237          105                6
# 238          108              -10
# 239           98                1
# 304           85               -7
# 305           83                8
# 306           93               -4
# 307           82                9
# 308           84                7
# 309           86               -2
# ...          ...              ...
# 2584          95               22
# 2585         106               -2
# 2586         103                3
# 2587         111              -15
# 2588          97               17
# 2697         114               34
# 2698         109               -7
# 2699         136              -25
# 2700         105                2
# 2701         120               -9
# 2702         111              -11
# 2729         107                6
# 2730          93               10
# 2731          94               17
# 2732         108                7
# 2815          99                6
# 2816         106               -1
# 2817         106               15
# 2818         109                3
# 2819          90                2
# 2878          97               12
# 2879         105                3
# 2880         110                4
# 2881          97                8
# 2962          92               13
# 2965         109                9
# 2966         106               -1
# 2969         109               -5
# 2972         110                4
# 2973         109               14
#
# [250 rows x 6 columns]

# %% [markdown]
# ## Visualizations for Data Exploration

# %%
v.make_density_plot(east_west_games,
                    'east_score',
                    'east_conference_points')

# %%
v.make_density_plot(east_west_games,
                    'west_score',
                    'west_conference_points')

# %%
v.make_density_plot(east_west_games,
                    'east_minus_west',
                    'east_minus_west')

# %% [markdown]
# ## Paired t-test
#
# Since each row is a game and each game has 2 variables of interest (East team score and West team score), we want to examine the difference in scores. We will conduct the paired t-test to compare the means of the East Conference team scores and West Conference team scores to see if there is a significant difference between the two scores (vs. there being no difference, East team score - West team score = 0).

# %% [markdown]
# ### Hypothesis Test Results

# %%
tests.conduct_pairedttest(east_west_games,
                          'east_score',
                          'west_score')
# Out:
# Given our null hypothesis (the difference in means is 0),
# the probability that our actual diference in means of 0.42
# is 0.5 standard deviations away is 0.62.
# Therefore we can NOT reject the null hypothesis.

# %% [markdown]
# ### Hypothesis Test Visualization

# %%
v.make_box_plot(east_west_games[['east_score', 'west_score']],
                east_west_games[['east_minus_west']],
                'distribution_of_points')

# %% [markdown]
# # Hypothesis 2: Which Team has Better Home Court Advantage

# %% [markdown]
# ## Shape dataframes for test

# %%
#west_teams
west_home_game_data = dp.make_home_df(games_data, 'West', 7)
west_home_game_data
# Out:
#         home_team_full_name  home_score_diff
# 1                 Utah Jazz               15
# 6              Phoenix Suns              -18
# 7     Oklahoma City Thunder               33
# 10             Phoenix Suns                6
# 12                Utah Jazz               11
# 14    Oklahoma City Thunder                1
# 15    Oklahoma City Thunder               12
# 16       Los Angeles Lakers               10
# 17        San Antonio Spurs                5
# 21                Utah Jazz                6
# 22       Los Angeles Lakers               14
# 23             Phoenix Suns                7
# 25             Phoenix Suns               -7
# 31             Phoenix Suns               12
# 33        San Antonio Spurs               -9
# 37       Los Angeles Lakers              -26
# 42                Utah Jazz                6
# 44    Oklahoma City Thunder                6
# 51          Houston Rockets                6
# 52          Houston Rockets                8
# 53                Utah Jazz               38
# 54    Oklahoma City Thunder                4
# 57        San Antonio Spurs               11
# 58          Houston Rockets               -3
# 59                Utah Jazz               30
# 60          Houston Rockets               -7
# 63                Utah Jazz                9
# 65                Utah Jazz                8
# 68             Phoenix Suns                7
# 71                Utah Jazz               11
# ...                     ...              ...
# 2881     Los Angeles Lakers               -8
# 2885              Utah Jazz              -18
# 2887        Houston Rockets                6
# 2888      San Antonio Spurs               16
# 2889     Los Angeles Lakers               12
# 2891     Los Angeles Lakers                4
# 2896        Houston Rockets               20
# 2899  Oklahoma City Thunder               12
# 2902  Golden State Warriors               17
# 2906        Houston Rockets               32
# 2908  Golden State Warriors               -4
# 2916  Oklahoma City Thunder              -13
# 2918              Utah Jazz               16
# 2920      San Antonio Spurs               10
# 2923      San Antonio Spurs              -14
# 2925              Utah Jazz               -3
# 2926  Golden State Warriors               -8
# 2928        Houston Rockets                7
# 2929      San Antonio Spurs               17
# 2931        Houston Rockets               -5
# 2936        Houston Rockets                4
# 2938  Golden State Warriors                5
# 2943  Golden State Warriors                4
# 2946  Golden State Warriors                6
# 2950        Houston Rockets                5
# 2962  Golden State Warriors              -13
# 2964  Golden State Warriors               22
# 2971  Golden State Warriors                3
# 2972  Golden State Warriors               -4
# 2973  Golden State Warriors              -14
#
# [1034 rows x 2 columns]

# %%
#east_teams
east_home_game_data = dp.make_home_df(games_data, 'East', 7)
east_home_game_data
# Out:
#       home_team_full_name  home_score_diff
# 0           Chicago Bulls               17
# 2           Orlando Magic               15
# 8           Chicago Bulls                7
# 9     Cleveland Cavaliers                7
# 11         Boston Celtics                7
# 18             Miami Heat              -21
# 20          Chicago Bulls               12
# 26        Detroit Pistons              -12
# 32        Detroit Pistons               -3
# 35        Detroit Pistons                4
# 36    Cleveland Cavaliers               25
# 39    Cleveland Cavaliers               -6
# 46         Boston Celtics               31
# 48          Chicago Bulls               29
# 55          Chicago Bulls               11
# 56          Orlando Magic               12
# 64          Chicago Bulls               -5
# 66          Chicago Bulls                8
# 67         Boston Celtics                3
# 69         Boston Celtics               -2
# 70          Chicago Bulls                8
# 73    Cleveland Cavaliers               16
# 75    Cleveland Cavaliers               -2
# 80          Chicago Bulls               13
# 81             Miami Heat               17
# 84        Detroit Pistons                8
# 88    Cleveland Cavaliers               16
# 90    Cleveland Cavaliers               18
# 91          Chicago Bulls               14
# 92          Chicago Bulls              -26
# ...                   ...              ...
# 2842      Detroit Pistons                7
# 2844        Chicago Bulls                7
# 2846  Cleveland Cavaliers               -1
# 2852        Chicago Bulls               13
# 2853       Boston Celtics              -15
# 2855        Chicago Bulls               -3
# 2858      Detroit Pistons                5
# 2860      Detroit Pistons               20
# 2861        Chicago Bulls               23
# 2868        Chicago Bulls                2
# 2870      Detroit Pistons               -6
# 2871      Detroit Pistons                9
# 2873        Chicago Bulls                2
# 2875        Chicago Bulls               -6
# 2876      Detroit Pistons                9
# 2877        Chicago Bulls               -9
# 2878      Detroit Pistons               12
# 2879      Detroit Pistons                3
# 2883        Chicago Bulls               14
# 2884       Boston Celtics               29
# 2886  Cleveland Cavaliers               27
# 2890      Detroit Pistons               13
# 2894       Boston Celtics                8
# 2897        Orlando Magic               -5
# 2904       Boston Celtics               10
# 2915        Orlando Magic              -22
# 2917      Detroit Pistons              -23
# 2924      Detroit Pistons              -16
# 2935       Boston Celtics              -12
# 2949       Boston Celtics               -7
#
# [797 rows x 2 columns]

# %% [markdown]
# ## ANOVA Test
#
# We want to compare a group of teams to see which team(s) has a significantly different home court (dis)advantage if one exists. We define home court advantage as the mean difference in score when a team plays a home game. We'll first conduct an ANOVA test to see if there exists a significant mean difference among teams. If there exists a significant mean, we'll conduct a ttest among all pairs of teams to compare their mean differences and identify the team(s) that led to our significant results in the ANOVA test.

# %% [markdown]
# ### West Conference Teams

# %%
tests.conduct_anova(west_home_game_data,
                    "home_team_full_name",
                    "home_score_diff")
# Out:
# F:  2.15
# p-value:  0.045544
# At least 1 team's home court advantage is statistically significant
#
# Phoenix Suns's home court advantage is statistically significantly
#  worse than
# Los Angeles Lakers's (t-stat: -2.1, p-value: 0.0367)
# Los Angeles Lakers's home court advantage is statistically significantly
#  better than
# Houston Rockets's (t-stat: 2.62, p-value: 0.0093)
# San Antonio Spurs's home court advantage is statistically significantly
#  better than
# Houston Rockets's (t-stat: 2.4, p-value: 0.0171)
# Houston Rockets's home court advantage is statistically significantly
#  worse than
# Golden State Warriors's (t-stat: -2.05, p-value: 0.0411)

# %%
v.make_ordered_boxplot(west_home_game_data,
                       'home_team_full_name',
                       'home_score_diff',
                       'east_home_games')

# %% [markdown]
# ### East Conference Teams

# %%
tests.conduct_anova(east_home_game_data,
                    'home_team_full_name',
                    'home_score_diff')
# Out:
# F:  0.46
# p-value:  0.837973
# No team's home court advantage is statistically significant
